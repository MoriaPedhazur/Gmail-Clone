# %% [markdown]
# <a href="https://colab.research.google.com/github/MoriaPedhazur/Gmail-Clone/blob/main/tools/cv_training/ipynb/classifier_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

PROJECT_ROOT = "/content/TheJoker"

# %cd /content

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

if not os.path.exists(PROJECT_ROOT):
    # !git clone https://{token}@github.com/InbalBen-Lulu/TheJoker.git

# %cd /content/TheJoker
# !git fetch
#---------change the branch----------
# !git checkout THEJ-73--setup
# !git pull

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Current dir:", os.getcwd())
print("Project root added to sys.path")
# Out:
# /content
# /content/TheJoker
# Already on 'THEJ-73--setup'
# Your branch is up to date with 'origin/THEJ-73--setup'.
# Already up to date.
# Current dir: /content/TheJoker
# Project root added to sys.path

# %%
import os
import sys

REPO_ROOT = "/content/TheJoker"

CORE_SRC = f"{REPO_ROOT}/packages/core/src"
CV_RUNTIME_SRC = f"{REPO_ROOT}/packages/cv_runtime/src"
CV_TRAINING_ROOT = f"{REPO_ROOT}/tools/cv_training"

for path in [CORE_SRC, CV_RUNTIME_SRC, CV_TRAINING_ROOT]:
    if path not in sys.path:
        sys.path.append(path)

print("Paths ready")
# Out:
# Paths ready

# %%
from domain.entities.game_state import GameState
from config import CLASSIFICATION_CONFIDENCE_THRESHOLD
from dto import DetectedTile
